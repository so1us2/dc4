# %%
from dc4.dc4_utils import play_game_player_player
from dc4.game import Game
from dc4.agent import Agent
from dc4.move import Move

# %%
# play_game_player_player() has been tested and seems to work.

# %%
play_game_player_player()
# Out:
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
#
# Move history: []
#
# R, make a legal move.0
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# R - - - - - -
#
# Move history: [R0 ]
#
# B, make a legal move.1
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# R B - - - - -
#
# Move history: [R0 B1 ]
#
# R, make a legal move.3
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# R B - R - - -
#
# Move history: [R0 B1 R3 ]
#
# B, make a legal move.2
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# R B B R - - -
#
# Move history: [R0 B1 R3 B2 ]
#
# R, make a legal move.6
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# R B B R - - R
#
# Move history: [R0 B1 R3 B2 R6 ]
#
# B, make a legal move.5
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# R B B R - B R
#
# Move history: [R0 B1 R3 B2 R6 B5 ]
#
# R, make a legal move.1
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - R - - - - -
# R B B R - B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 ]
#
# B, make a legal move.4
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - R - - - - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 ]
#
# R, make a legal move.3
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - R - R - - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 ]
#
# B, make a legal move.2
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - R B R - - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 ]
#
# R, make a legal move.2
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - R - - - -
# - R B R - - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 ]
#
# B, make a legal move.3
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - - - - - -
# - - R B - - -
# - R B R - - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 ]
#
# R, make a legal move.2
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - R - - - -
# - - R B - - -
# - R B R - - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 ]
#
# B, make a legal move.3
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - R B - - -
# - - R B - - -
# - R B R - - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 ]
#
# R, make a legal move.4
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - R B - - -
# - - R B - - -
# - R B R R - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 ]
#
# B, make a legal move.4
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - R B - - -
# - - R B B - -
# - R B R R - -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 ]
#
# R, make a legal move.5
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - R B - - -
# - - R B B - -
# - R B R R R -
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 ]
#
# B, make a legal move.6
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - R B - - -
# - - R B B - -
# - R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 ]
#
# R, make a legal move.5
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - R B - - -
# - - R B B R -
# - R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 ]
#
# B, make a legal move.5
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - R B - B -
# - - R B B R -
# - R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 ]
#
# R, make a legal move.4
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - R B R B -
# - - R B B R -
# - R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 ]
#
# B, make a legal move.6
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - R B R B -
# - - R B B R B
# - R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 ]
#
# R, make a legal move.0
# Current game status:
# B to move
# - - - - - - -
# - - - - - - -
# - - R B R B -
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 ]
#
# B, make a legal move.6
# Current game status:
# R to move
# - - - - - - -
# - - - - - - -
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 ]
#
# R, make a legal move.6
# Current game status:
# B to move
# - - - - - - -
# - - - - - - R
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 ]
#
# B, make a legal move.5
# Current game status:
# R to move
# - - - - - - -
# - - - - - B R
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 ]
#
# R, make a legal move.6
# Current game status:
# B to move
# - - - - - - R
# - - - - - B R
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 ]
#
# B, make a legal move.5
# Current game status:
# R to move
# - - - - - B R
# - - - - - B R
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 ]
#
# R, make a legal move.4
# Current game status:
# B to move
# - - - - - B R
# - - - - R B R
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 ]
#
# B, make a legal move.4
# Current game status:
# R to move
# - - - - B B R
# - - - - R B R
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 ]
#
# R, make a legal move.3
# Current game status:
# B to move
# - - - - B B R
# - - - R R B R
# - - R B R B B
# - - R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 ]
#
# B, make a legal move.1
# Current game status:
# R to move
# - - - - B B R
# - - - R R B R
# - - R B R B B
# - B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 ]
#
# R, make a legal move.0
# Current game status:
# B to move
# - - - - B B R
# - - - R R B R
# - - R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 ]
#
# B, make a legal move.0
# Current game status:
# R to move
# - - - - B B R
# - - - R R B R
# B - R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 B0 ]
#
# R, make a legal move.1
# Current game status:
# B to move
# - - - - B B R
# - - - R R B R
# B R R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 B0 R1 ]
#
# B, make a legal move.0
# Current game status:
# R to move
# - - - - B B R
# B - - R R B R
# B R R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 B0 R1 B0 ]
#
# R, make a legal move.2
# Current game status:
# B to move
# - - - - B B R
# B - R R R B R
# B R R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 B0 R1 B0 R2 ]
# B, make a legal move.1
# Current game status:
# R to move
# - - - - B B R
# B B R R R B R
# B R R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 B0 R1 B0 R2 B1 ]
#
# R, make a legal move.0
# Current game status:
# B to move
# R - - - B B R
# B B R R R B R
# B R R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 B0 R1 B0 R2 B1 R0 ]
#
# B, make a legal move.2
# Current game status:
# R to move
# R - B - B B R
# B B R R R B R
# B R R B R B B
# R B R B B R B
# R R B R R R B
# R B B R B B R
#
# Move history: [R0 B1 R3 B2 R6 B5 R1 B4 R3 B2 R2 B3 R2 B3 R4 B4 R5 B6 R5 B5 R4 B6 R0 B6 R6 B5 R6 B5 R4 B4 R3 B1 R0 B0 R1 B0 R2 B1 R0 B2 ]
#
# R, make a legal move.3
# R WINS!
